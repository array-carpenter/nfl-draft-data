# %% [markdown]
# # NFL Combine Drill Distributions
#
# Beeswarm plots for all six combine drills, colored by position group. Two versions per drill:
#
# 1. **Combine + Pro Day** — every recorded measurement from 2007 to 2026
# 2. **Official Combine Only** — NFL Scouting Combine measurements from 2006 to 2026
#
# Uses `ggbeeswarm::geom_quasirandom` with custom position-group colors (colorblind-safe) and `theme_spade` branding.

# %%
library(ggplot2)
library(ggbeeswarm)
library(dplyr)
library(showtext)
library(arrow)
library(magick)

font_add_google("Karla", "karla")
showtext_auto()
showtext_opts(dpi = 300)

# Make inline plots large in the notebook
options(repr.plot.width = 20, repr.plot.height = 11)

theme_spade <- function(base_size = 12) {
  theme_minimal(base_size = base_size) +
    theme(
      text = element_text(family = "karla", color = "#333333"),
      plot.background = element_rect(fill = "#DDEBEC", color = NA),
      panel.background = element_rect(fill = "#DDEBEC", color = NA),
      plot.title = element_text(face = "bold", size = 36, margin = margin(b = 5)),
      plot.title.position = "plot",
      plot.subtitle = element_text(size = 22, color = "#666666", margin = margin(b = 15)),
      plot.caption = element_text(size = 18, color = "#888888", hjust = 0),
      plot.caption.position = "plot",
      panel.grid.major = element_line(color = "#cccccc", linewidth = 0.3),
      panel.grid.minor = element_blank(),
      legend.background = element_rect(fill = "#DDEBEC", color = NA),
      legend.key = element_rect(fill = "#DDEBEC", color = NA),
      plot.margin = margin(t = 20, r = 20, b = 20, l = 20)
    )
}

# Position group colors
pos_colors <- c(
  "DB"    = "#2e2d88",
  "WR"    = "#1e75ff",
  "HB/FB" = "#7267bd",
  "LB"    = "#e7174b",
  "TE"    = "#f08233",
  "QB"    = "#F0E442",
  "K/P"   = "#999998",
  "DL"    = "#17becf",
  "LS"    = "#333233",
  "OL"    = "#3db34b"
)

# Logo for compositing (relative to notebook dir)
logo_path <- file.path("..", "spade_logo.png")

output_dir <- file.path("..", "output", "beeswarm")
dir.create(output_dir, recursive = TRUE, showWarnings = FALSE)

# %%
# --- Load combine + pro day data ---
df_all <- read_parquet(file.path("..", "data", "combine_pro_day.parquet")) |>
  mutate(POS_GP = case_when(
    POS_GP %in% c("EDGE", "DT") ~ "DL",
    POS_GP %in% c("RB", "FB")   ~ "HB/FB",
    POS_GP %in% c("K", "P", "SPEC") ~ "K/P",
    TRUE ~ POS_GP
  )) |>
  filter(POS_GP %in% names(pos_colors)) |>
  mutate(POS_GP = factor(POS_GP, levels = names(pos_colors)))

cat(sprintf("Combine + Pro Day: %s rows (%d–%d)\n",
            format(nrow(df_all), big.mark = ","), min(df_all$Year), max(df_all$Year)))

# --- Load official combine only ---
df_official <- read_parquet(file.path("..", "data", "combine_official.parquet")) |>
  rename(
    Year            = year,
    `40 Yard`       = forty_yard_dash,
    `Vert Leap (in)` = vertical_jump,
    `Broad Jump (in)` = broad_jump,
    `3Cone`         = three_cone_drill,
    Shuttle         = twenty_yard_shuttle,
    `Bench Press`   = bench_press,
    POS_GP          = position_group
  ) |>
  mutate(POS_GP = case_when(
    POS_GP %in% c("EDGE", "DT") ~ "DL",
    POS_GP %in% c("RB", "FB")   ~ "HB/FB",
    POS_GP %in% c("K", "P", "SPEC") ~ "K/P",
    TRUE ~ POS_GP
  )) |>
  filter(POS_GP %in% names(pos_colors)) |>
  mutate(POS_GP = factor(POS_GP, levels = names(pos_colors)))

cat(sprintf("Official Combine:  %s rows (%d–%d)\n",
            format(nrow(df_official), big.mark = ","), min(df_official$Year), max(df_official$Year)))

# %%
make_beeswarm <- function(data, col, title, subtitle_prefix, xlabel, lo, hi, step, filename) {
  subset <- data |>
    filter(!is.na(.data[[col]]), .data[[col]] >= lo, .data[[col]] <= hi)
  n_obs <- nrow(subset)
  yr_min <- min(subset$Year)
  yr_max <- max(subset$Year)

  p <- ggplot(subset, aes(x = .data[[col]], y = 0, color = POS_GP)) +
    geom_quasirandom(
      groupOnX = TRUE, width = 0.4,
      size = 1, alpha = 0.6
    ) +
    scale_color_manual(values = pos_colors, name = NULL) +
    labs(
      title = title,
      subtitle = paste0(subtitle_prefix, " from ", yr_min, "–", yr_max,
                         " (n = ", format(n_obs, big.mark = ","), ")"),
      x = xlabel,
      y = NULL,
      caption = "Ray Carpenter | TheSpade.Substack.com | @csv_enjoyer | data: Various sources"
    ) +
    scale_x_continuous(breaks = seq(lo, hi, step), limits = c(lo, hi), expand = expansion(mult = 0.01)) +
    theme_spade() +
    theme(
      axis.text.x = element_text(size = 18),
      axis.title.x = element_text(size = 20),
      axis.text.y = element_blank(),
      panel.grid.major.y = element_blank(),
      legend.position = "top",
      legend.text = element_text(size = 16, face = "bold"),
      legend.key.size = unit(1.2, "lines")
    ) +
    guides(color = guide_legend(nrow = 1, override.aes = list(size = 4, alpha = 1)))

  # Save to temp, composite logo, write final
  tmp <- tempfile(fileext = ".png")
  ggsave(tmp, plot = p, width = 16, height = 9, dpi = 300, bg = "#DDEBEC")

  plot_img <- image_read(tmp)
  plot_info <- image_info(plot_img)
  logo <- image_read(logo_path) |>
    image_trim() |>
    image_scale(geometry_size_pixels(height = round(plot_info$height * 0.08)))
  logo_info <- image_info(logo)
  x_offset <- plot_info$width - logo_info$width - round(plot_info$width * 0.02)
  y_offset <- round(plot_info$height * 0.02)
  final <- image_composite(plot_img, logo, offset = paste0("+", x_offset, "+", y_offset))

  out_path <- file.path(output_dir, filename)
  image_write(final, out_path)
  unlink(tmp)
  cat(sprintf("Saved %s\n", out_path))
  p
}

# %%
# --- 40-Yard Dash ---
make_beeswarm(
  data = df_all, col = "40 Yard",
  title = "NFL Combine & Pro Day 40-Yard Dash Times by Position",
  subtitle_prefix = "Every combine and pro day measurement",
  xlabel = "40-Yard Dash (seconds)",
  lo = 4.2, hi = 5.5, step = 0.2,
  filename = "forty_spread.png"
)

make_beeswarm(
  data = df_official, col = "40 Yard",
  title = "NFL Combine 40-Yard Dash Times by Position",
  subtitle_prefix = "Official NFL Scouting Combine measurements",
  xlabel = "40-Yard Dash (seconds)",
  lo = 4.2, hi = 5.5, step = 0.2,
  filename = "forty_spread_official.png"
)

# %%
# --- Vertical Leap ---
make_beeswarm(
  data = df_all, col = "Vert Leap (in)",
  title = "NFL Combine & Pro Day Vertical Leap by Position",
  subtitle_prefix = "Every combine and pro day measurement",
  xlabel = "Vertical Leap (inches)",
  lo = 20, hi = 46, step = 2,
  filename = "vert_leap_spread.png"
)

make_beeswarm(
  data = df_official, col = "Vert Leap (in)",
  title = "NFL Combine Vertical Leap by Position",
  subtitle_prefix = "Official NFL Scouting Combine measurements",
  xlabel = "Vertical Leap (inches)",
  lo = 20, hi = 46, step = 2,
  filename = "vert_leap_spread_official.png"
)

# %%
# --- Broad Jump ---
make_beeswarm(
  data = df_all, col = "Broad Jump (in)",
  title = "NFL Combine & Pro Day Broad Jump by Position",
  subtitle_prefix = "Every combine and pro day measurement",
  xlabel = "Broad Jump (inches)",
  lo = 84, hi = 142, step = 4,
  filename = "broad_jump_spread.png"
)

make_beeswarm(
  data = df_official, col = "Broad Jump (in)",
  title = "NFL Combine Broad Jump by Position",
  subtitle_prefix = "Official NFL Scouting Combine measurements",
  xlabel = "Broad Jump (inches)",
  lo = 84, hi = 142, step = 4,
  filename = "broad_jump_spread_official.png"
)

# %%
# --- 3-Cone Drill ---
make_beeswarm(
  data = df_all, col = "3Cone",
  title = "NFL Combine & Pro Day 3-Cone Drill by Position",
  subtitle_prefix = "Every combine and pro day measurement",
  xlabel = "3-Cone Drill (seconds)",
  lo = 6.2, hi = 8.2, step = 0.2,
  filename = "three_cone_spread.png"
)

make_beeswarm(
  data = df_official, col = "3Cone",
  title = "NFL Combine 3-Cone Drill by Position",
  subtitle_prefix = "Official NFL Scouting Combine measurements",
  xlabel = "3-Cone Drill (seconds)",
  lo = 6.2, hi = 8.2, step = 0.2,
  filename = "three_cone_spread_official.png"
)

# %%
# --- 20-Yard Shuttle ---
make_beeswarm(
  data = df_all, col = "Shuttle",
  title = "NFL Combine & Pro Day 20-Yard Shuttle by Position",
  subtitle_prefix = "Every combine and pro day measurement",
  xlabel = "20-Yard Shuttle (seconds)",
  lo = 3.8, hi = 5.0, step = 0.2,
  filename = "shuttle_spread.png"
)

make_beeswarm(
  data = df_official, col = "Shuttle",
  title = "NFL Combine 20-Yard Shuttle by Position",
  subtitle_prefix = "Official NFL Scouting Combine measurements",
  xlabel = "20-Yard Shuttle (seconds)",
  lo = 3.8, hi = 5.0, step = 0.2,
  filename = "shuttle_spread_official.png"
)

# %%
# --- Bench Press ---
make_beeswarm(
  data = df_all, col = "Bench Press",
  title = "NFL Combine & Pro Day Bench Press by Position",
  subtitle_prefix = "Every combine and pro day measurement",
  xlabel = "Bench Press (reps at 225 lbs)",
  lo = 5, hi = 50, step = 5,
  filename = "bench_press_spread.png"
)

make_beeswarm(
  data = df_official, col = "Bench Press",
  title = "NFL Combine Bench Press by Position",
  subtitle_prefix = "Official NFL Scouting Combine measurements",
  xlabel = "Bench Press (reps at 225 lbs)",
  lo = 5, hi = 50, step = 5,
  filename = "bench_press_spread_official.png"
)
