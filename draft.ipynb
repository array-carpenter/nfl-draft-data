# %% [markdown]
# Using Euclidean Distance and Cosine Similarity to Compare NFL Draft Prospects with Pros

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# Most similar professional for Israel Abanikanda is Zack Moss with a similarity score of 100.00
# Most similar professional for Devon Achane is D'Andre Swift with a similarity score of 100.00
# Most similar professional for Tank Bigsby is Zonovan Knight with a similarity score of 100.00
# Most similar professional for Chase Brown is Brian Robinson with a similarity score of 99.99
# Most similar professional for Zach Charbonnet is Zack Moss with a similarity score of 99.99
# Most similar professional for Travis Dye is Chris Evans with a similarity score of 99.99
# Most similar professional for Zach Evans is Trey Sermon with a similarity score of 100.00
# Most similar professional for Jahmyr Gibbs is Alvin Kamara with a similarity score of 99.94
# Most similar professional for Eric Gray is Chris Evans with a similarity score of 100.00
# Most similar professional for Evan Hull is Dare Ogunbowale with a similarity score of 99.98
# Most similar professional for Mohamed Ibrahim is Kenneth Walker with a similarity score of 99.98
# Most similar professional for Roschon Johnson is Breece Hall with a similarity score of 100.00
# Most similar professional for DeWayne McBride is Kenneth Walker with a similarity score of 99.86
# Most similar professional for Kenny McIntosh is Alvin Kamara with a similarity score of 99.98
# Most similar professional for Kendre Miller is Khalil Herbert with a similarity score of 99.99
# Most similar professional for Keaton Mitchell is Michael Carter with a similarity score of 100.00
# Most similar professional for Cam Peoples is Kenneth Walker with a similarity score of 99.97
# Most similar professional for Deneric Prince is James Robinson with a similarity score of 100.00
# Most similar professional for Bijan Robinson is D'Andre Swift with a similarity score of 99.99
# Most similar professional for Chris Rodriguez Jr. is Kenneth Walker with a similarity score of 99.98
# Most similar professional for Tyjae Spears is Michael Carter with a similarity score of 100.00
# Most similar professional for Tavion Thomas is AJ Dillon with a similarity score of 99.94
# Most similar professional for SaRodorick Thompson is Eno Benjamin with a similarity score of 99.98
# Most similar professional for Sean Tucker is Breece Hall with a similarity score of 99.99
# Most similar professional for Deuce Vaughn is Dare Ogunbowale with a similarity score of 99.94

# %% [markdown]
# Running Back Comparison

# %%
df = pd.read_csv("NFL Draft Data - RB.csv")
# Define function to calculate aggregated stats for a player based on years played
def aggregate_stats(df, player_name):
    player_stats = df[df['Name'] == player_name]
    years_played = player_stats['YP'].iloc[0]
    agg_stats = player_stats[['Att', 'RushYds', 'RushTD', 'Rec', 'RecYds', 'RecTD']].sum()
    agg_stats /= years_played
    return agg_stats

# Create separate DataFrames for prospects and professionals
prospects = df[df['Prospect'] == 1]
professionals = df[df['Prospect'] == 0]

# Iterate over each prospect and find the most similar professional
for _, prospect in prospects.iterrows():
    prospect_stats = aggregate_stats(df, prospect['Name']).values.reshape(1, -1)
    professional_stats = np.vstack(professionals.apply(lambda x: aggregate_stats(df, x['Name']), axis=1).values)
    similarity_scores = cosine_similarity(prospect_stats, professional_stats)
    most_similar_idx = np.argmax(similarity_scores)
    most_similar = professionals.iloc[most_similar_idx]
    similarity_score = similarity_scores[0][most_similar_idx] * 100
    print(f"Most similar professional for {prospect['Name']} is {most_similar['Name']} with a similarity score of {similarity_score:.2f}")
# Out:
# Most similar professional for Israel Abanikanda is Zack Moss with a similarity score of 100.00
# Most similar professional for Devon Achane is D'Andre Swift with a similarity score of 100.00
# Most similar professional for Tank Bigsby is Zonovan Knight with a similarity score of 100.00
# Most similar professional for Chase Brown is Brian Robinson with a similarity score of 99.99
# Most similar professional for Zach Charbonnet is Zack Moss with a similarity score of 99.99
# Most similar professional for Travis Dye is Chris Evans with a similarity score of 99.99
# Most similar professional for Zach Evans is Trey Sermon with a similarity score of 100.00
# Most similar professional for Jahmyr Gibbs is Alvin Kamara with a similarity score of 99.94
# Most similar professional for Eric Gray is Chris Evans with a similarity score of 100.00
# Most similar professional for Evan Hull is Dare Ogunbowale with a similarity score of 99.98
# Most similar professional for Mohamed Ibrahim is Kenneth Walker with a similarity score of 99.98
# Most similar professional for Roschon Johnson is Breece Hall with a similarity score of 100.00
# Most similar professional for DeWayne McBride is Kenneth Walker with a similarity score of 99.86
# Most similar professional for Kenny McIntosh is Alvin Kamara with a similarity score of 99.98
# Most similar professional for Kendre Miller is Khalil Herbert with a similarity score of 99.99
# Most similar professional for Keaton Mitchell is Michael Carter with a similarity score of 100.00
# Most similar professional for Cam Peoples is Kenneth Walker with a similarity score of 99.97
# Most similar professional for Deneric Prince is James Robinson with a similarity score of 100.00
# Most similar professional for Bijan Robinson is D'Andre Swift with a similarity score of 99.99
# Most similar professional for Chris Rodriguez Jr. is Kenneth Walker with a similarity score of 99.98
# Most similar professional for Tyjae Spears is Michael Carter with a similarity score of 100.00
# Most similar professional for Tavion Thomas is AJ Dillon with a similarity score of 99.94
# Most similar professional for SaRodorick Thompson is Eno Benjamin with a similarity score of 99.98
# Most similar professional for Sean Tucker is Breece Hall with a similarity score of 99.99
# Most similar professional for Deuce Vaughn is Dare Ogunbowale with a similarity score of 99.94

# %%
# Define function to calculate Euclidean distance between two players
def euclidean_distance(x, y):
    return np.sqrt(np.sum((x - y) ** 2))

    # Compute min and max values of distance metric
min_distance_range = np.inf
max_distance_range = -np.inf
for _, player1 in df.iterrows():
    for _, player2 in df.iterrows():
        if player1['Name'] != player2['Name']:
            distance = euclidean_distance(aggregate_stats(df, player1['Name']), aggregate_stats(df, player2['Name']))
            if distance < min_distance_range:
                min_distance_range = distance
            if distance > max_distance_range:
                max_distance_range = distance

# Define function to calculate aggregated stats for a player based on years played
def aggregate_stats(df, player_name):
    player_stats = df[df['Name'] == player_name]
    years_played = player_stats['YP'].iloc[0]
    agg_stats = player_stats[['Att', 'RushYds', 'RushTD', 'Rec', 'RecYds', 'RecTD']].sum()
    agg_stats /= years_played
    return agg_stats

# Create separate DataFrames for prospects and professionals
prospects = df[df['Prospect'] == 1]
professionals = df[df['Prospect'] == 0]

# Iterate over each prospect and find the most similar professional
for _, prospect in prospects.iterrows():
    prospect_stats = aggregate_stats(df, prospect['Name'])
    min_distance = np.inf
    most_similar = None
    for _, professional in professionals.iterrows():
        professional_stats = aggregate_stats(df, professional['Name'])
        distance = euclidean_distance(prospect_stats, professional_stats)
        if distance < min_distance:
            min_distance = distance
            most_similar = professional
    similarity_score = 100 * (1 - (min_distance - min_distance_range) / (max_distance_range - min_distance_range))
    print(f"Most similar professional for {prospect['Name']} is {most_similar['Name']} with a similarity score of {similarity_score:.2f}")
# Out:
# Most similar professional for Israel Abanikanda is Rakeem Boyd with a similarity score of 99.63
# Most similar professional for Devon Achane is Elijah Mitchell with a similarity score of 97.61
# Most similar professional for Tank Bigsby is Cam Akers with a similarity score of 98.82
# Most similar professional for Chase Brown is Salvon Ahmed with a similarity score of 98.96
# Most similar professional for Zach Charbonnet is Elijah Mitchell with a similarity score of 98.78
# Most similar professional for Travis Dye is Dare Ogunbowale with a similarity score of 96.68
# Most similar professional for Zach Evans is Salvon Ahmed with a similarity score of 98.79
# Most similar professional for Jahmyr Gibbs is Alvin Kamara with a similarity score of 95.12
# Most similar professional for Eric Gray is Jerrion Ealy with a similarity score of 97.97
# Most similar professional for Evan Hull is La'Mical Perine with a similarity score of 97.47
# Most similar professional for Mohamed Ibrahim is Larry Rountree with a similarity score of 97.57
# Most similar professional for Roschon Johnson is Brian Robinson with a similarity score of 98.90
# Most similar professional for DeWayne McBride is Nick Chubb with a similarity score of 95.37
# Most similar professional for Kenny McIntosh is James Cook with a similarity score of 97.87
# Most similar professional for Kendre Miller is Anthony McFarland with a similarity score of 98.34
# Most similar professional for Keaton Mitchell is Zack Moss with a similarity score of 98.23
# Most similar professional for Cam Peoples is Khalil Herbert with a similarity score of 97.47
# Most similar professional for Deneric Prince is Raymond Calais with a similarity score of 98.33
# Most similar professional for Bijan Robinson is Mark Ingram with a similarity score of 96.40
# Most similar professional for Chris Rodriguez Jr. is Tyler Allgeier with a similarity score of 95.38
# Most similar professional for Tyjae Spears is Trey Sermon with a similarity score of 98.80
# Most similar professional for Tavion Thomas is Isaiah Pacheco with a similarity score of 97.02
# Most similar professional for SaRodorick Thompson is Brian Robinson with a similarity score of 98.96
# Most similar professional for Sean Tucker is Mark Ingram with a similarity score of 98.32
# Most similar professional for Deuce Vaughn is Saquon Barkley with a similarity score of 95.50

# %% [markdown]
# QB Comparison

# %%
df = pd.read_csv("NFL Draft Data - QB.csv")
# Define function to calculate aggregated stats for a player based on years played
def aggregate_stats(df, player_name):
    player_stats = df[df['Name'] == player_name]
    years_played = player_stats['YP'].iloc[0]
    agg_stats = player_stats[['Cmp','PassAtt','Pct','PassTD','Int', 'RushYds', 'RushTD']].sum()
    agg_stats /= years_played
    return agg_stats

# Create separate DataFrames for prospects and professionals
prospects = df[df['Prospect'] == 1]
professionals = df[df['Prospect'] == 0]

# Iterate over each prospect and find the most similar professional
for _, prospect in prospects.iterrows():
    prospect_stats = aggregate_stats(df, prospect['Name']).values.reshape(1, -1)
    professional_stats = np.vstack(professionals.apply(lambda x: aggregate_stats(df, x['Name']), axis=1).values)
    similarity_scores = cosine_similarity(prospect_stats, professional_stats)
    most_similar_idx = np.argmax(similarity_scores)
    most_similar = professionals.iloc[most_similar_idx]
    similarity_score = similarity_scores[0][most_similar_idx] * 100
    print(f"Most similar professional for {prospect['Name']} is {most_similar['Name']} with a similarity score of {similarity_score:.2f}")
# Out:
# Most similar professional for Stetson Bennett is Pat Mahomes with a similarity score of 99.91
# Most similar professional for Malik Cunningham is Kyler Murray with a similarity score of 99.95
# Most similar professional for Max Duggan is Zac Thomas with a similarity score of 99.92
# Most similar professional for Jake Haener is Jack Coan with a similarity score of 99.94
# Most similar professional for Jaren Hall is Skylar Thompson with a similarity score of 99.81
# Most similar professional for Hendon Hooker is Dustin Crum with a similarity score of 99.93
# Most similar professional for Will Levis is Russell Wilson with a similarity score of 99.91
# Most similar professional for Tanner McKee is Jack Coan with a similarity score of 99.94
# Most similar professional for Aidan O'Connell is Carson Strong with a similarity score of 99.98
# Most similar professional for Anthony Richardson is Kyler Murray with a similarity score of 99.91
# Most similar professional for C.J. Stroud is Teddy Bridgewater with a similarity score of 99.92
# Most similar professional for Dorian Thompson-Robinson is Ian Book with a similarity score of 99.99
# Most similar professional for Clayton Tune is Trevor Lawrence with a similarity score of 99.97
# Most similar professional for Bryce Young is Teddy Bridgewater with a similarity score of 99.94

# %%
df = pd.read_csv("NFL Draft Data - QB.csv")
# Define function to calculate Euclidean distance between two players
def euclidean_distance(x, y):
    return np.sqrt(np.sum((x - y) ** 2))

    # Compute min and max values of distance metric
min_distance_range = np.inf
max_distance_range = -np.inf
for _, player1 in df.iterrows():
    for _, player2 in df.iterrows():
        if player1['Name'] != player2['Name']:
            distance = euclidean_distance(aggregate_stats(df, player1['Name']), aggregate_stats(df, player2['Name']))
            if distance < min_distance_range:
                min_distance_range = distance
            if distance > max_distance_range:
                max_distance_range = distance

# Define function to calculate aggregated stats for a player based on years played
def aggregate_stats(df, player_name):
    player_stats = df[df['Name'] == player_name]
    years_played = player_stats['YP'].iloc[0]
    agg_stats = player_stats[['Cmp','PassAtt','Pct','PassTD','Int', 'RushYds', 'RushTD']].sum()
    agg_stats /= years_played
    return agg_stats

# Create separate DataFrames for prospects and professionals
prospects = df[df['Prospect'] == 1]
professionals = df[df['Prospect'] == 0]

# Iterate over each prospect and find the most similar professional
for _, prospect in prospects.iterrows():
    prospect_stats = aggregate_stats(df, prospect['Name'])
    min_distance = np.inf
    most_similar = None
    for _, professional in professionals.iterrows():
        professional_stats = aggregate_stats(df, professional['Name'])
        distance = euclidean_distance(prospect_stats, professional_stats)
        if distance < min_distance:
            min_distance = distance
            most_similar = professional
    similarity_score = 100 * (1 - (min_distance - min_distance_range) / (max_distance_range - min_distance_range))
    print(f"Most similar professional for {prospect['Name']} is {most_similar['Name']} with a similarity score of {similarity_score:.2f}")
# Out:
# Most similar professional for Stetson Bennett is Tua Tagovailoa with a similarity score of 99.08
# Most similar professional for Malik Cunningham is Malik Willis with a similarity score of 92.32
# Most similar professional for Max Duggan is Sam Ehlinger with a similarity score of 95.60
# Most similar professional for Jake Haener is Jacob Eason with a similarity score of 98.48
# Most similar professional for Jaren Hall is Skylar Thompson with a similarity score of 99.43
# Most similar professional for Hendon Hooker is Dustin Crum with a similarity score of 99.41
# Most similar professional for Will Levis is Skylar Thompson with a similarity score of 98.48
# Most similar professional for Tanner McKee is Jacob Eason with a similarity score of 99.55
# Most similar professional for Aidan O'Connell is Carson Strong with a similarity score of 100.00
# Most similar professional for Anthony Richardson is D'Eriq King with a similarity score of 96.44
# Most similar professional for C.J. Stroud is Kyle Trask with a similarity score of 98.80
# Most similar professional for Dorian Thompson-Robinson is Ian Book with a similarity score of 99.28
# Most similar professional for Clayton Tune is Steven Montez with a similarity score of 98.39
# Most similar professional for Bryce Young is Matthew Stafford with a similarity score of 98.67

# %% [markdown]
# WR Comparison

# %%
df = pd.read_csv("NFL Draft Data - WR.csv")

# Replace NaN values with column means
df.fillna(df.mean(), inplace=True)

# Define function to calculate aggregated stats for a player based on years played
def aggregate_stats(df, player_name):
    player_stats = df[df['Name'] == player_name]
    years_played = player_stats['YP'].iloc[0]
    agg_stats = player_stats[['Rec','Yds','TD']].sum()
    agg_stats /= years_played
    return agg_stats

# Create separate DataFrames for prospects and professionals
prospects = df[df['Prospect'] == 1]
professionals = df[df['Prospect'] == 0]

# Iterate over each prospect and find the most similar professional
for _, prospect in prospects.iterrows():
    prospect_stats = aggregate_stats(df, prospect['Name']).values.reshape(1, -1)
    professional_stats = np.vstack(professionals.apply(lambda x: aggregate_stats(df, x['Name']), axis=1).values)
    similarity_scores = cosine_similarity(prospect_stats, professional_stats)
    most_similar_idx = np.argmax(similarity_scores)
    most_similar = professionals.iloc[most_similar_idx]
    similarity_score = similarity_scores[0][most_similar_idx] * 100
    print(f"Most similar professional for {prospect['Name']} is {most_similar['Name']} with a similarity score of {similarity_score:.2f}")
# Out:
# Most similar professional for Jordan Addison is Chase Claypool with a similarity score of 100.00
# C:\Users\RaymondCarpenter\AppData\Local\Temp\ipykernel_21088\3268878743.py:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)
# Most similar professional for Ronnie Bell is AJ Brown with a similarity score of 100.00
# Most similar professional for Jake Bobo is Anthony Schwartz with a similarity score of 100.00
# Most similar professional for Kayshon Boutte is DJ Moore with a similarity score of 100.00
# Most similar professional for Jalen Brooks is Austin Mack with a similarity score of 100.00
# Most similar professional for Jason Brownlee is Tyrie Cleveland with a similarity score of 100.00
# Most similar professional for Jacob Copeland is Erik Ezukanma with a similarity score of 100.00
# Most similar professional for Derius Davis is John Metchie with a similarity score of 100.00
# Most similar professional for Nathaniel Dell is DJ Moore with a similarity score of 100.00
# Most similar professional for Dontay Demus Jr. is Erik Ezukanma with a similarity score of 100.00
# Most similar professional for Demario Douglas is Amon-Ra St. Brown with a similarity score of 100.00
# Most similar professional for Josh Downs is Parris Campbell with a similarity score of 100.00
# Most similar professional for Grant DuBose is Isaiah Hodgins with a similarity score of 100.00
# Most similar professional for Zay Flowers is Jalen Reagor with a similarity score of 100.00
# Most similar professional for Bryce Ford-Wheaton is Cornell Powell with a similarity score of 100.00
# Most similar professional for Antoine Green is Dyami Brown with a similarity score of 100.00
# Most similar professional for Jadon Haselwood is Amari Rodgers with a similarity score of 100.00
# Most similar professional for Malik Heath is Kadarius Toney with a similarity score of 100.00
# Most similar professional for Elijah Higgins is Wan'Dale Robinson with a similarity score of 100.00
# Most similar professional for Xavier Hutchinson is Wan'Dale Robinson with a similarity score of 100.00
# Most similar professional for Jalin Hyatt is Calvin Johnson with a similarity score of 100.00
# Most similar professional for Andrei Iosivas is Chase Claypool with a similarity score of 100.00
# Most similar professional for Kearis Jackson is Juwan Johnson with a similarity score of 100.00
# Most similar professional for Rakim Jarrett is Elijah Moore with a similarity score of 100.00
# Most similar professional for Michael Jefferson is Dyami Brown with a similarity score of 100.00
# Most similar professional for Jaray Jenkins is Garrett Wilson with a similarity score of 100.00
# Most similar professional for CJ Johnson is Rashod Bateman with a similarity score of 100.00
# Most similar professional for Quentin Johnston is D'Wayne Eskridge with a similarity score of 100.00
# Most similar professional for Charlie Jones is Freddie Swain with a similarity score of 99.89
# Most similar professional for Malik Knowles is Michael Pittman with a similarity score of 100.00
# Most similar professional for Matt Landers is Jameson Williams with a similarity score of 100.00
# Most similar professional for Marvin Mims is Jameson Williams with a similarity score of 100.00
# Most similar professional for Jonathan Mingo is Erik Ezukanma with a similarity score of 100.00
# Most similar professional for Jalen Moreno-Cropper is Chase Claypool with a similarity score of 100.00
# Most similar professional for Puka Nacua is Rashod Bateman with a similarity score of 100.00
# Most similar professional for Joseph Ngata is Juwan Johnson with a similarity score of 100.00
# Most similar professional for Trey Palmer is Kadarius Toney with a similarity score of 100.00
# Most similar professional for A.T. Perry is Garrett Wilson with a similarity score of 100.00
# Most similar professional for Jayden Reed is K.J. Osborn with a similarity score of 100.00
# Most similar professional for Rashee Rice is Kadarius Toney with a similarity score of 100.00
# Most similar professional for Tyler Scott is Calvin Johnson with a similarity score of 100.00
# Most similar professional for Justin Shorter is Collin Johnson with a similarity score of 100.00
# Most similar professional for Jaxon Smith-Njigba is Dax Milne with a similarity score of 100.00
# Most similar professional for Cedric Tillman is George Pickens with a similarity score of 100.00
# Most similar professional for Mitchell Tinsley is James Proche with a similarity score of 100.00
# Most similar professional for Tre Tucker is Elijah Moore with a similarity score of 100.00
# Most similar professional for Parker Washington is Austin Mack with a similarity score of 100.00
# Most similar professional for Jalen Wayne is Bryan Edwards with a similarity score of 100.00
# Most similar professional for Dontayvion Wicks is D'Wayne Eskridge with a similarity score of 100.00
# Most similar professional for Michael Wilson is Van Jefferson with a similarity score of 100.00

# %%
df = pd.read_csv("NFL Draft Data - WR.csv")
# Define function to calculate Euclidean distance between two players
def euclidean_distance(x, y):
    return np.sqrt(np.sum((x - y) ** 2))

    # Compute min and max values of distance metric
min_distance_range = np.inf
max_distance_range = -np.inf
for _, player1 in df.iterrows():
    for _, player2 in df.iterrows():
        if player1['Name'] != player2['Name']:
            distance = euclidean_distance(aggregate_stats(df, player1['Name']), aggregate_stats(df, player2['Name']))
            if distance < min_distance_range:
                min_distance_range = distance
            if distance > max_distance_range:
                max_distance_range = distance

# Define function to calculate aggregated stats for a player based on years played
def aggregate_stats(df, player_name):
    player_stats = df[df['Name'] == player_name]
    years_played = player_stats['YP'].iloc[0]
    agg_stats = player_stats[['Rec','Yds','TD']].sum()
    agg_stats /= years_played
    return agg_stats

# Create separate DataFrames for prospects and professionals
prospects = df[df['Prospect'] == 1]
professionals = df[df['Prospect'] == 0]

# Iterate over each prospect and find the most similar professional
for _, prospect in prospects.iterrows():
    prospect_stats = aggregate_stats(df, prospect['Name'])
    min_distance = np.inf
    most_similar = None
    for _, professional in professionals.iterrows():
        professional_stats = aggregate_stats(df, professional['Name'])
        distance = euclidean_distance(prospect_stats, professional_stats)
        if distance < min_distance:
            min_distance = distance
            most_similar = professional
    similarity_score = 100 * (1 - (min_distance - min_distance_range) / (max_distance_range - min_distance_range))
    print(f"Most similar professional for {prospect['Name']} is {most_similar['Name']} with a similarity score of {similarity_score:.2f}")

# %% [markdown]
# Takeaways
#
# More features and more data could yield better results. My goal for the 2024 NFL Draft is to increase this dataset and perhaps find a more efficient way to do so since most of my work on this project was spent attempting to collect data.
